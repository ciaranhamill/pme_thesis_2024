# %% [markdown]
# # Wave 1 Analysis - 9 Year Old Cohort
#
# ### 2 Datasets for Wave 1:
# - Cohort dataset (details about each student, e.g. demographics, academic scores, etc)
# - Time Use dataset (details of the time use diary completed by students)

# %% [markdown]
# ## Import Required Packages

# %%
import math
import statistics
import pandas as pd
import numpy as np
import warnings
from pandas.core.common import SettingWithCopyWarning
from sklearn.preprocessing import MinMaxScaler
from statsmodels.stats.weightstats import ztest as ztest

# Silence copy warning & allow all columns and rows to be seen
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=pd.errors.PerformanceWarning)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Import Raw Data - Cohort Dataset

# %%
# Specify which columns we want to use (using the data dictionaries)
required_cols = ['ID', 'Wgt_9yr', 'Gross_9yr', 'mathsls', 'mma5ap2']

# Read in data
cohort_data = pd.read_csv('0020-01 GUI Child Cohort Wave 1/0020-01 GUI Child Cohort Wave 1_Data/9 Year Cohort Data/CSV/GUI Data_9YearCohort.csv', index_col= 'ID', usecols=required_cols)

# Check the number of rows and columns
cohort_data.shape
# Out:
# (8568, 4)

# %% [markdown]
# ## Exploratory Data Analysis - Cohort Dataset
#
# - Check the datatypes of each column
# - Describe the data - min, max, mean, stdev, etc
# - View the first 10 rows of the data

# %%
cohort_data.dtypes
# Out:
# Wgt_9yr      float64
# Gross_9yr    float64
# mma5ap2        int64
# mathsls       object
# dtype: object

# %%
cohort_data.describe()
# Out:
#            Wgt_9yr    Gross_9yr      mma5ap2
# count  8568.000000  8568.000000  8568.000000
# mean      0.999993     6.593909     1.514006
# std       0.769568     5.074497     0.499833
# min       0.200535     1.322316     1.000000
# 25%       0.509936     3.362492     1.000000
# 50%       0.766355     5.053313     2.000000
# 75%       1.230138     8.111474     2.000000
# max       4.615382    30.433616     2.000000

# %% [markdown]
# *Below output is removed from Git as access to the data is to be requested from Growing up in Ireland.*

# %%
cohort_data.head(10)

# %% [markdown]
# ## Clean Raw Cohort Dataset
#
# - Standardise the format of all empty/missing values to use Python NULL so we can use Python .dropna(), .isna(), etc
# - Drop any rows where the maths score is missing
# - Set the datatype of the maths score as a decimal
# - Create 2 new columns - the scaled maths score (1-100) and the percentile rank using the scaled maths score

# %%
# NULL values are filled with whitespace, replace with Python numpy NULL value
cohort_data = cohort_data.replace(r'^\s*$', np.nan, regex=True)

# Drop any students who are missing a maths score
cohort_data = cohort_data[cohort_data.mathsls.isna() == False]

print(f'Shape of dataframe after dropping students missing a maths score: {cohort_data.shape}')

# correct datatype from object to decimal(numeric)
cohort_data.mathsls = cohort_data.mathsls.astype('float64')

# Scale Maths logit scores to 1-100 using MinMaxScaler
scaler = MinMaxScaler(feature_range=(1,100))

cohort_data['SCALED_MATHSLS'] = scaler.fit_transform(cohort_data[['mathsls']])

# Calculate Percentile rank for students with maths score
cohort_data['MATHSLS_PERCENTILE_RANK'] = cohort_data['SCALED_MATHSLS'].rank(pct=True) * 100


print(f'Shape of dataframe after adding 2 new columns: {cohort_data.shape}')
# Out:
# Shape of dataframe after dropping students missing a maths score: (8449, 4)
# Shape of dataframe after adding 2 new columns: (8449, 6)

# %% [markdown]
# ### View first 10 rows after data cleaning

# %% [markdown]
# *Below output is removed from Git as access to the data is to be requested from Growing up in Ireland.*

# %%
cohort_data.head(10)

# %% [markdown]
# ## Import Raw Data - Time Use Dataset

# %%
timeuse_data = pd.read_csv('0020-01 GUI Child Cohort Wave 1/0020-01 GUI Child Cohort Wave 1_Data/Time Use Data/GUI Data_9YearCohort_TimeUse.txt', index_col= 'ID')

timeuse_data.shape
# Out:
# (6228, 500)

# %% [markdown]
# ## Exploratory Data Analysis - Time Use Dataset
#
# - Check the datatypes of each column
# - Describe the data - min, max, mean, stdev, etc
# - View the first 10 rows of the data

# %%
timeuse_data.dtypes
# Out:
# wgttime9yr      float64
# grosstime9yr    float64
# DiaryDay          int64
# DiaryDat         object
# diarymonth        int64
# weekend           int64
# term              int64
# t00_1_A1          int64
# t00_1_A2         object
# t00_1_A3         object
# t00_1_A4         object
# t00_1_A5         object
# t00_2_A1          int64
# t00_2_A2         object
# t00_2_A3         object
# t00_2_A4         object
# t00_2_A5         object
# t00_3_A1          int64
# t00_3_A2         object
# t00_3_A3         object
# t00_3_A4         object
# t00_3_A5         object
# t00_4_A1          int64
# t00_4_A2         object
# t00_4_A3         object
# t00_4_A4         object
# t00_4_A5         object
# t01_1_A1          int64
# t01_1_A2         object
# t01_1_A3         object
# t01_1_A4         object
# t01_1_A5         object
# t01_2_A1          int64
# t01_2_A2         object
# t01_2_A3         object
# t01_2_A4         object
# t01_2_A5         object
# t01_3_A1          int64
# t01_3_A2         object
# t01_3_A3         object
# t01_3_A4         object
# t01_3_A5         object
# t01_4_A1          int64
# t01_4_A2         object
# t01_4_A3         object
# t01_4_A4         object
# t01_4_A5         object
# t02_1_A1          int64
# t02_1_A2         object
# t02_1_A3         object
# t02_1_A4         object
# t02_1_A5         object
# t02_2_A1          int64
# t02_2_A2         object
# t02_2_A3         object
# t02_2_A4         object
# t02_2_A5         object
# t02_3_A1          int64
# t02_3_A2         object
# t02_3_A3         object
# t02_3_A4         object
# t02_3_A5         object
# t02_4_A1          int64
# t02_4_A2         object
# t02_4_A3         object
# t02_4_A4         object
# t02_4_A5         object
# t03_1_A1          int64
# t03_1_A2         object
# t03_1_A3         object
# t03_1_A4         object
# t03_1_A5         object
# t03_2_A1          int64
# t03_2_A2         object
# t03_2_A3         object
# t03_2_A4         object
# t03_2_A5         object
# t03_3_A1          int64
# t03_3_A2         object
# t03_3_A3         object
# t03_3_A4         object
# t03_3_A5         object
# t03_4_A1          int64
# t03_4_A2         object
# t03_4_A3         object
# t03_4_A4         object
# t03_4_A5         object
# t04_1_A1          int64
# t04_1_A2         object
# t04_1_A3         object
# t04_1_A4         object
# t04_1_A5         object
# t04_2_A1          int64
# t04_2_A2         object
# t04_2_A3         object
# t04_2_A4         object
# t04_2_A5         object
# t04_3_A1          int64
# t04_3_A2         object
# t04_3_A3         object
# t04_3_A4         object
# t04_3_A5         object
# t04_4_A1          int64
# t04_4_A2         object
# t04_4_A3         object
# t04_4_A4         object
# t04_4_A5         object
# t05_1_A1          int64
# t05_1_A2         object
# t05_1_A3         object
# t05_1_A4         object
# t05_1_A5         object
# t05_2_A1          int64
# t05_2_A2         object
# t05_2_A3         object
# t05_2_A4         object
# t05_2_A5         object
# t05_3_A1          int64
# t05_3_A2         object
# t05_3_A3         object
# t05_3_A4         object
# t05_3_A5         object
# t05_4_A1          int64
# t05_4_A2         object
# t05_4_A3         object
# t05_4_A4         object
# t05_4_A5         object
# t06_1_A1          int64
# t06_1_A2         object
# t06_1_A3         object
# t06_1_A4         object
# t06_1_A5         object
# t06_2_A1          int64
# t06_2_A2         object
# t06_2_A3         object
# t06_2_A4         object
# t06_2_A5         object
# t06_3_A1          int64
# t06_3_A2         object
# t06_3_A3         object
# t06_3_A4         object
# t06_3_A5         object
# t06_4_A1          int64
# t06_4_A2         object
# t06_4_A3         object
# t06_4_A4         object
# t06_4_A5         object
# t07_1_A1          int64
# t07_1_A2         object
# t07_1_A3         object
# t07_1_A4         object
# t07_1_A5         object
# t07_2_A1          int64
# t07_2_A2         object
# t07_2_A3         object
# t07_2_A4         object
# t07_2_A5         object
# t07_3_A1          int64
# t07_3_A2         object
# t07_3_A3         object
# t07_3_A4         object
# t07_3_A5         object
# t07_4_A1          int64
# t07_4_A2         object
# t07_4_A3         object
# t07_4_A4         object
# t07_4_A5         object
# t08_1_A1          int64
# t08_1_A2         object
# t08_1_A3         object
# t08_1_A4         object
# t08_1_A5         object
# t08_2_A1          int64
# t08_2_A2         object
# t08_2_A3         object
# t08_2_A4         object
# t08_2_A5         object
# t08_3_A1          int64
# t08_3_A2         object
# t08_3_A3         object
# t08_3_A4         object
# t08_3_A5         object
# t08_4_A1          int64
# t08_4_A2         object
# t08_4_A3         object
# t08_4_A4         object
# t08_4_A5         object
# t09_1_A1          int64
# t09_1_A2         object
# t09_1_A3         object
# t09_1_A4         object
# t09_1_A5         object
# t09_2_A1          int64
# t09_2_A2         object
# t09_2_A3         object
# t09_2_A4         object
# t09_2_A5         object
# t09_3_A1          int64
# t09_3_A2         object
# t09_3_A3         object
# t09_3_A4         object
# t09_3_A5         object
# t09_4_A1          int64
# t09_4_A2         object
# t09_4_A3         object
# t09_4_A4         object
# t09_4_A5         object
# t10_1_A1          int64
# t10_1_A2         object
# t10_1_A3         object
# t10_1_A4         object
# t10_1_A5         object
# t10_2_A1          int64
# t10_2_A2         object
# t10_2_A3         object
# t10_2_A4         object
# t10_2_A5         object
# t10_3_A1          int64
# t10_3_A2         object
# t10_3_A3         object
# t10_3_A4         object
# t10_3_A5         object
# t10_4_A1          int64
# t10_4_A2         object
# t10_4_A3         object
# t10_4_A4         object
# t10_4_A5         object
# t11_1_A1          int64
# t11_1_A2         object
# t11_1_A3         object
# t11_1_A4         object
# t11_1_A5         object
# t11_2_A1          int64
# t11_2_A2         object
# t11_2_A3         object
# t11_2_A4         object
# t11_2_A5         object
# t11_3_A1          int64
# t11_3_A2         object
# t11_3_A3         object
# t11_3_A4         object
# t11_3_A5         object
# t11_4_A1          int64
# t11_4_A2         object
# t11_4_A3         object
# t11_4_A4         object
# t11_4_A5         object
# t12_1_P1          int64
# t12_1_P2         object
# t12_1_P3         object
# t12_1_P4         object
# t12_1_P5         object
# t12_2_P1          int64
# t12_2_P2         object
# t12_2_P3         object
# t12_2_P4         object
# t12_2_P5         object
# t12_3_P1          int64
# t12_3_P2         object
# t12_3_P3         object
# t12_3_P4         object
# t12_3_P5         object
# t12_4_P1          int64
# t12_4_P2         object
# t12_4_P3         object
# t12_4_P4         object
# t12_4_P5         object
# t01_1_P1          int64
# t01_1_P2         object
# t01_1_P3         object
# t01_1_P4         object
# t01_1_P5         object
# t01_2_P1          int64
# t01_2_P2         object
# t01_2_P3         object
# t01_2_P4         object
# t01_2_P5         object
# t01_3_P1          int64
# t01_3_P2         object
# t01_3_P3         object
# t01_3_P4         object
# t01_3_P5         object
# t01_4_P1          int64
# t01_4_P2         object
# t01_4_P3         object
# t01_4_P4         object
# t01_4_P5         object
# t02_1_P1          int64
# t02_1_P2         object
# t02_1_P3         object
# t02_1_P4         object
# t02_1_P5         object
# t02_2_P1          int64
# t02_2_P2         object
# t02_2_P3         object
# t02_2_P4         object
# t02_2_P5         object
# t02_3_P1          int64
# t02_3_P2         object
# t02_3_P3         object
# t02_3_P4         object
# t02_3_P5         object
# t02_4_P1          int64
# t02_4_P2         object
# t02_4_P3         object
# t02_4_P4         object
# t02_4_P5         object
# t03_1_P1          int64
# t03_1_P2         object
# t03_1_P3         object
# t03_1_P4         object
# t03_1_P5         object
# t03_2_P1          int64
# t03_2_P2         object
# t03_2_P3         object
# t03_2_P4         object
# t03_2_P5         object
# t03_3_P1          int64
# t03_3_P2         object
# t03_3_P3         object
# t03_3_P4         object
# t03_3_P5         object
# t03_4_P1          int64
# t03_4_P2         object
# t03_4_P3         object
# t03_4_P4         object
# t03_4_P5         object
# t04_1_P1          int64
# t04_1_P2         object
# t04_1_P3         object
# t04_1_P4         object
# t04_1_P5         object
# t04_2_P1          int64
# t04_2_P2         object
# t04_2_P3         object
# t04_2_P4         object
# t04_2_P5         object
# t04_3_P1          int64
# t04_3_P2         object
# t04_3_P3         object
# t04_3_P4         object
# t04_3_P5         object
# t04_4_P1          int64
# t04_4_P2         object
# t04_4_P3         object
# t04_4_P4         object
# t04_4_P5         object
# t05_1_P1          int64
# t05_1_P2         object
# t05_1_P3         object
# t05_1_P4         object
# t05_1_P5         object
# t05_2_P1          int64
# t05_2_P2         object
# t05_2_P3         object
# t05_2_P4         object
# t05_2_P5         object
# t05_3_P1          int64
# t05_3_P2         object
# t05_3_P3         object
# t05_3_P4         object
# t05_3_P5         object
# t05_4_P1          int64
# t05_4_P2         object
# t05_4_P3         object
# t05_4_P4         object
# t05_4_P5         object
# t06_1_P1          int64
# t06_1_P2         object
# t06_1_P3         object
# t06_1_P4         object
# t06_1_P5         object
# t06_2_P1          int64
# t06_2_P2         object
# t06_2_P3         object
# t06_2_P4         object
# t06_2_P5         object
# t06_3_P1          int64
# t06_3_P2         object
# t06_3_P3         object
# t06_3_P4         object
# t06_3_P5         object
# t06_4_P1          int64
# t06_4_P2         object
# t06_4_P3         object
# t06_4_P4         object
# t06_4_P5         object
# t07_1_P1          int64
# t07_1_P2         object
# t07_1_P3         object
# t07_1_P4         object
# t07_1_P5         object
# t07_2_P1          int64
# t07_2_P2         object
# t07_2_P3         object
# t07_2_P4         object
# t07_2_P5         object
# t07_3_P1          int64
# t07_3_P2         object
# t07_3_P3         object
# t07_3_P4         object
# t07_3_P5         object
# t07_4_P1          int64
# t07_4_P2         object
# t07_4_P3         object
# t07_4_P4         object
# t07_4_P5         object
# t08_1_P1          int64
# t08_1_P2         object
# t08_1_P3         object
# t08_1_P4         object
# t08_1_P5         object
# t08_2_P1          int64
# t08_2_P2         object
# t08_2_P3         object
# t08_2_P4         object
# t08_2_P5         object
# t08_3_P1          int64
# t08_3_P2         object
# t08_3_P3         object
# t08_3_P4         object
# t08_3_P5         object
# t08_4_P1          int64
# t08_4_P2         object
# t08_4_P3         object
# t08_4_P4         object
# t08_4_P5         object
# t09_1_P1          int64
# t09_1_P2         object
# t09_1_P3         object
# t09_1_P4         object
# t09_1_P5         object
# t09_2_P1          int64
# t09_2_P2         object
# t09_2_P3         object
# t09_2_P4         object
# t09_2_P5         object
# t09_3_P1          int64
# t09_3_P2         object
# t09_3_P3         object
# t09_3_P4         object
# t09_3_P5         object
# t09_4_P1          int64
# t09_4_P2         object
# t09_4_P3         object
# t09_4_P4         object
# t09_4_P5         object
# t10_1_P1          int64
# t10_1_P2         object
# t10_1_P3         object
# t10_1_P4         object
# t10_1_P5         object
# t10_2_P1          int64
# t10_2_P2         object
# t10_2_P3         object
# t10_2_P4         object
# t10_2_P5         object
# t10_3_P1          int64
# t10_3_P2         object
# t10_3_P3         object
# t10_3_P4         object
# t10_3_P5         object
# t10_4_P1          int64
# t10_4_P2         object
# t10_4_P3         object
# t10_4_P4         object
# t10_4_P5         object
# t11_1_P1          int64
# t11_1_P2         object
# t11_1_P3         object
# t11_1_P4         object
# t11_1_P5         object
# t11_2_P1          int64
# t11_2_P2         object
# t11_2_P3         object
# t11_2_P4         object
# t11_2_P5         object
# t11_3_P1          int64
# t11_3_P2         object
# t11_3_P3         object
# t11_3_P4         object
# t11_3_P5         object
# t11_4_P1          int64
# t11_4_P2         object
# t11_4_P3         object
# t11_4_P4         object
# t11_4_P5         object
# t1_1              int64
# t1_2              int64
# t1_3              int64
# t1_4              int64
# t1_5              int64
# t1_6              int64
# t1_7              int64
# t1_8              int64
# t1_9              int64
# t1_10             int64
# T2                int64
# T3               object
# T4                int64
# dtype: object

# %%
timeuse_data.describe()
# Out:
#         wgttime9yr  grosstime9yr     DiaryDay   diarymonth      weekend  \
# count  6228.000000   6228.000000  6228.000000  6228.000000  6228.000000
# mean      1.000003      9.071475     3.706808     8.067759     1.230893
# std       0.938916      8.517328     1.978714     3.325677     0.421438
# min       0.161143      1.461798     1.000000     1.000000     1.000000
# 25%       0.467334      4.239396     2.000000     5.000000     1.000000
# 50%       0.698816      6.339274     4.000000     9.000000     1.000000
# 75%       1.164133     10.560377     5.000000    11.000000     1.000000
# max       8.953163     81.218182     7.000000    12.000000     2.000000
#
#               term     t00_1_A1     t00_2_A1     t00_3_A1     t00_4_A1  \
# count  6228.000000  6228.000000  6228.000000  6228.000000  6228.000000
# mean      1.140816     1.022479     1.014933     1.010758     1.007065
# std       0.347859     0.590712     0.484149     0.414968     0.317492
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000     1.000000     1.000000
# 50%       1.000000     1.000000     1.000000     1.000000     1.000000
# 75%       1.000000     1.000000     1.000000     1.000000     1.000000
# max       2.000000    22.000000    22.000000    22.000000    18.000000
#
#           t01_1_A1     t01_2_A1     t01_3_A1     t01_4_A1     t02_1_A1  \
# count  6228.000000  6228.000000  6228.000000  6228.000000  6228.000000
# mean
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     2.000000     2.000000     2.000000     2.000000
# 50%       2.000000     2.000000     2.000000     2.000000     2.000000
# 75%       2.000000     2.000000     2.000000     2.000000     2.000000
# max       9.000000     9.000000     9.000000     9.000000     9.000000
#
#               t1_9        t1_10           T2           T4
# count  6228.000000  6228.000000  6228.000000  6228.000000
# mean      2.707771     2.682241     2.795601     2.197174
# std       2.147004     2.157004     2.350280     2.366523
# min       1.000000     1.000000     1.000000     1.000000
# 25%       2.000000     2.000000     1.000000     1.000000
# 50%       2.000000     2.000000     2.000000     1.000000
# 75%       2.000000     2.000000     3.000000     2.000000
# max       9.000000     9.000000     9.000000     9.000000

# %% [markdown]
# *Below output is removed from Git as access to the data is to be requested from Growing up in Ireland.*

# %%
timeuse_data.head()

# %% [markdown]
# ## Clean Raw Time Use Dataset
#
# - Standardise the format of all empty/missing values to use Python NULL so we can use Python .dropna(), .isna(), etc

# %%
# NULL values are filled with whitespace, replace with Python numpy NULL value
timeuse_data = timeuse_data.replace(r'^\s*$', np.nan, regex=True)

# Check % of NULLs across each column, e.g. 0.5 = 50% of values in this column are NULL
timeuse_data.isnull().mean() * 100
# Out:
# wgttime9yr        0.000000
# grosstime9yr      0.000000
# DiaryDay          0.000000
# DiaryDat          0.000000
# diarymonth        0.000000
# weekend           0.000000
# term              0.000000
# t00_1_A1          0.000000
# t00_1_A2         99.983943
# t00_1_A3        100.000000
# t00_1_A4        100.000000
# t00_1_A5        100.000000
# t00_2_A1          0.000000
# t00_2_A2         99.983943
# t00_2_A3        100.000000
# t00_2_A4        100.000000
# t00_2_A5        100.000000
# t00_3_A1          0.000000
# t00_3_A2         99.983943
# t00_3_A3        100.000000
# t00_3_A4        100.000000
# t00_3_A5        100.000000
# t00_4_A1          0.000000
# t00_4_A2         99.983943
# t00_4_A3        100.000000
# t00_4_A4        100.000000
# t00_4_A5        100.000000
# t01_1_A1          0.000000
# t01_1_A2         99.983943
# t01_1_A3        100.000000
# t01_1_A4        100.000000
# t01_1_A5        100.000000
# t01_2_A1          0.000000
# t01_2_A2         99.983943
# t01_2_A3        100.000000
# t01_2_A4        100.000000
# t01_2_A5        100.000000
# t01_3_A1          0.000000
# t01_3_A2         99.983943
# t01_3_A3        100.000000
# t01_3_A4        100.000000
# t01_3_A5        100.000000
# t01_4_A1          0.000000
# t01_4_A2         99.983943
# t01_4_A3        100.000000
# t01_4_A4        100.000000
# t01_4_A5        100.000000
# t02_1_A1          0.000000
# t02_1_A2         99.983943
# t02_1_A3        100.000000
# t02_1_A4        100.000000
# t02_1_A5        100.000000
# t02_2_A1          0.000000
# t02_2_A2         99.983943
# t02_2_A3        100.000000
# t02_2_A4        100.000000
# t02_2_A5        100.000000
# t02_3_A1          0.000000
# t02_3_A2         99.983943
# t02_3_A3        100.000000
# t02_3_A4        100.000000
# t02_3_A5        100.000000
# t02_4_A1          0.000000
# t02_4_A2         99.983943
# t02_4_A3        100.000000
# t02_4_A4        100.000000
# t02_4_A5        100.000000
# t03_1_A1          0.000000
# t03_1_A2         99.967887
# t03_1_A3        100.000000
# t03_1_A4        100.000000
# t03_1_A5        100.000000
# t03_2_A1          0.000000
# t03_2_A2         99.967887
# t03_2_A3        100.000000
# t09_1_A1          0.000000
# t09_1_A2         98.442518
# t09_1_A3         99.727039
# t09_1_A4         99.967887
# t09_1_A5        100.000000
# t09_2_A1          0.000000
# t09_2_A2         98.972383
# t09_2_A3         99.887604
# t09_2_A4         99.983943
# t09_2_A5        100.000000
# t09_3_A1          0.000000
# t09_3_A2         99.116891
# t09_3_A3         99.887604
# t09_3_A4        100.000000
# t09_3_A5        100.000000
# t09_4_A1          0.000000
# t09_4_A2         99.149004
# t09_4_A3         99.919717
# t09_4_A4        100.000000
# t09_4_A5        100.000000
# t10_1_A1          0.000000
# t10_1_A2         98.988439
# t10_1_A3         99.935774
# t10_1_A4        100.000000
# t10_1_A5        100.000000
# t10_2_A1          0.000000
# t10_2_A2         98.892100
# t10_2_A3         99.903661
# t10_2_A4         99.983943
# t10_2_A5        100.000000
# t10_3_A1          0.000000
# t10_3_A2         99.165061
# t10_3_A3         99.951830
# t10_3_A4         99.983943
# t10_3_A5        100.000000
# t10_4_A1          0.000000
# t10_4_A2         99.165061
# t10_4_A3         99.967887
# t10_4_A4         99.983943
# t10_4_A5        100.000000
# t11_1_A1          0.000000
# t11_1_A2         99.036609
# t11_1_A3         99.935774
# t11_1_A4         99.983943
# t11_1_A5         99.983943
# t11_2_A1          0.000000
# t11_2_A2         99.261400
# t11_2_A3         99.951830
# t11_2_A4        100.000000
# t11_2_A5        100.000000
# t11_3_A1          0.000000
# t11_3_A2         99.165061
# t11_3_A3         99.935774
# t11_3_A4        100.000000
# t11_3_A5        100.000000
# t11_4_A1          0.000000
# t11_4_A2         99.213231
# t11_4_A3         99.935774
# t11_4_A4        100.000000
# t11_4_A5        100.000000
# t12_1_P1          0.000000
# t12_1_P2         99.084778
# t12_1_P3         99.951830
# t12_1_P4         99.983943
# t12_1_P5        100.000000
# t12_2_P1          0.000000
# t12_2_P2         99.020552
# t12_2_P3         99.935774
# t12_2_P4         99.983943
# t12_2_P5        100.000000
# t12_3_P1          0.000000
# t12_3_P2         99.052665
# t12_3_P3         99.903661
# t12_3_P4        100.000000
# t12_3_P5        100.000000
# t12_4_P1          0.000000
# t12_4_P2         99.181118
# t12_4_P3         99.903661
# t12_4_P4        100.000000
# t12_4_P5        100.000000
# t01_1_P1          0.000000
# t01_1_P2         98.859987
# t01_1_P3         99.919717
# t01_1_P4        100.000000
# t01_1_P5        100.000000
# t01_2_P1          0.000000
# t01_2_P2         99.004496
# t01_2_P3         99.951830
# t01_2_P4        100.000000
# t01_2_P5        100.000000
# t01_3_P1          0.000000
# t01_3_P2         99.181118
# t01_3_P3         99.951830
# t01_3_P4        100.000000
# t01_3_P5        100.000000
# t01_4_P1          0.000000
# t01_4_P2         99.245344
# t01_4_P3         99.935774
# t01_4_P4        100.000000
# t01_4_P5        100.000000
# t02_1_P1          0.000000
# t02_1_P2         99.068722
# t02_1_P3         99.967887
# t02_1_P4        100.000000
# t02_1_P5        100.000000
# t02_2_P1          0.000000
# t02_2_P2         98.876044
# t02_2_P3         99.983943
# t02_2_P4        100.000000
# t02_2_P5        100.000000
# t02_3_P1          0.000000
# t02_3_P2         98.587026
# t02_3_P3         99.951830
# t02_3_P4         99.967887
# t02_3_P5        100.000000
# t02_4_P1          0.000000
# t02_4_P2         98.330122
# t02_4_P3         99.935774
# t02_4_P4        100.000000
# t02_4_P5        100.000000
# t03_1_P1          0.000000
# t03_1_P2         97.222222
# t03_1_P3         99.823378
# t03_1_P4         99.983943
# t03_1_P5         99.983943
# t03_2_P1          0.000000
# t03_2_P2         97.238279
# t03_2_P3         99.710983
# t03_2_P4         99.967887
# t03_2_P5        100.000000
# t03_3_P1          0.000000
# t03_3_P2         97.013487
# t03_3_P3         99.743096
# t03_3_P4         99.967887
# t03_3_P5        100.000000
# t03_4_P1          0.000000
# t03_4_P2         96.772640
# t03_4_P3         99.678870
# t03_4_P4         99.951830
# t03_4_P5        100.000000
# t04_1_P1          0.000000
# t04_1_P2         96.355170
# t04_1_P3         99.534361
# t04_1_P4         99.903661
# t04_1_P5        100.000000
# t04_2_P1          0.000000
# t04_2_P2         96.483622
# t04_2_P3         99.502248
# t04_2_P4         99.887604
# t04_2_P5         99.983943
# t04_3_P1          0.000000
# t04_3_P2         96.788696
# t04_3_P3         99.518304
# t04_3_P4         99.839435
# t04_3_P5        100.000000
# t04_4_P1          0.000000
# t04_4_P2         96.547848
# t04_4_P3         99.566474
# t04_4_P4         99.839435
# t04_4_P5         99.983943
# t05_1_P1          0.000000
# t05_1_P2         96.162492
# t05_1_P3         99.486191
# t05_1_P4         99.839435
# t05_1_P5         99.983943
# t05_2_P1          0.000000
# t05_2_P2         95.985870
# t05_2_P3         99.405909
# t05_2_P4         99.839435
# t05_2_P5        100.000000
# t05_3_P1          0.000000
# t05_3_P2         96.130379
# t05_3_P3         99.550417
# t05_3_P4         99.887604
# t05_3_P5         99.983943
# t05_4_P1          0.000000
# t05_4_P2         96.146435
# t05_4_P3         99.518304
# t05_4_P4         99.903661
# t05_4_P5         99.983943
# t06_1_P1          0.000000
# t06_1_P2         95.536288
# t06_1_P3         99.309570
# t06_1_P4         99.823378
# t06_1_P5         99.935774
# t06_2_P1          0.000000
# t06_2_P2         95.600514
# t06_2_P3         99.373796
# t06_2_P4         99.839435
# t06_2_P5         99.935774
# t06_3_P1          0.000000
# t06_3_P2         96.017983
# t06_3_P3         99.293513
# t06_3_P4         99.823378
# t06_3_P5         99.935774
# t06_4_P1          0.000000
# t06_4_P2         95.905588
# t06_4_P3         99.357739
# t06_4_P4         99.871548
# t06_4_P5         99.967887
# t07_1_P1          0.000000
# t07_1_P2         95.793192
# t07_1_P3         99.277457
# t07_1_P4         99.855491
# t07_1_P5         99.935774
# t07_2_P1          0.000000
# t07_2_P2         96.050096
# t07_2_P3         99.213231
# t07_2_P4         99.791265
# t07_2_P5         99.935774
# t07_3_P1          0.000000
# t07_3_P2         95.921644
# t07_3_P3         99.341683
# t07_3_P4         99.807322
# t07_3_P5         99.951830
# t07_4_P1          0.000000
# t07_4_P2         96.082209
# t07_4_P3         99.405909
# t07_4_P4         99.775209
# t07_4_P5         99.935774
# t08_1_P1          0.000000
# t08_1_P2         95.921644
# t08_1_P3         99.389852
# t08_1_P4         99.791265
# t08_1_P5         99.983943
# t08_2_P1          0.000000
# t08_2_P2         96.066153
# t08_2_P3         99.405909
# t08_2_P4         99.823378
# t08_2_P5         99.983943
# t08_3_P1          0.000000
# t08_3_P2         96.242775
# t08_3_P3         99.518304
# t08_3_P4         99.919717
# t08_3_P5         99.983943
# t08_4_P1          0.000000
# t08_4_P2         96.483622
# t08_4_P3         99.614644
# t08_4_P4         99.951830
# t08_4_P5        100.000000
# t09_1_P1          0.000000
# t09_1_P2         97.719974
# t09_1_P3         99.743096
# t09_1_P4         99.967887
# t09_1_P5         99.983943
# t09_2_P1          0.000000
# t09_2_P2         98.298009
# t09_2_P3         99.807322
# t09_2_P4         99.967887
# t09_2_P5         99.983943
# t09_3_P1          0.000000
# t09_3_P2         98.779705
# t09_3_P3         99.903661
# t09_3_P4         99.983943
# t09_3_P5        100.000000
# t09_4_P1          0.000000
# t09_4_P2         99.197174
# t09_4_P3         99.951830
# t09_4_P4        100.000000
# t09_4_P5        100.000000
# t10_1_P1          0.000000
# t10_1_P2         99.470135
# t10_1_P3         99.983943
# t10_1_P4        100.000000
# t10_1_P5        100.000000
# t10_2_P1          0.000000
# t10_2_P2         99.662813
# t10_2_P3        100.000000
# t10_2_P4        100.000000
# t10_2_P5        100.000000
# t10_3_P1          0.000000
# t10_3_P2         99.743096
# t10_3_P3         99.983943
# t10_3_P4        100.000000
# t10_3_P5        100.000000
# t10_4_P1          0.000000
# t10_4_P2         99.823378
# t10_4_P3        100.000000
# t10_4_P4        100.000000
# t10_4_P5        100.000000
# t11_1_P1          0.000000
# t11_1_P2         99.871548
# t11_1_P3        100.000000
# t11_1_P4        100.000000
# t11_1_P5        100.000000
# t11_2_P1          0.000000
# t11_2_P2         99.903661
# t11_2_P3        100.000000
# t11_2_P4        100.000000
# t11_2_P5        100.000000
# t11_3_P1          0.000000
# t11_3_P2         99.903661
# t11_3_P3        100.000000
# t11_3_P4        100.000000
# t11_3_P5        100.000000
# t11_4_P1          0.000000
# t11_4_P2         99.903661
# t11_4_P3        100.000000
# t11_4_P4        100.000000
# t11_4_P5        100.000000
# t1_1              0.000000
# t1_2              0.000000
# t1_3              0.000000
# t1_4              0.000000
# t1_5              0.000000
# t1_6              0.000000
# t1_7              0.000000
# t1_8              0.000000
# t1_9              0.000000
# t1_10             0.000000
# T2                0.000000
# T3               91.201028
# T4                0.000000
# dtype: float64

# %% [markdown]
# The format of the time use data is as follows:
#
# sample column name = **t00_1_A1**
#
# This decoded = time 00:00, block 1/4 (i.e. first 15mins of 00hrs), A1 = activity 1

# %%
# get all column names that begin with 't'
timeuse_cols = [col for col in timeuse_data if col.startswith('t')]

# specify columns we want to remove
cols_to_remove = ['term', 't1_1', 't1_2', 't1_3', 't1_4', 't1_5', 't1_6', 't1_7', 't1_8', 't1_9', 't1_10']

# final columns to be used is list 1 - list2
timeuse_cols = list(set(timeuse_cols) - set(cols_to_remove))

# sort the columns
timeuse_cols.sort()

# %% [markdown]
# ## Feature Engineering Time Use Dataset
#
# The following features are added to the time use dataset:
# - The number of 15minute intervals each student spent gaming (using the data dictionary, gaming = activity '13')
# - The total number of minutes each student spent gaming (i.e. number of intervals * 15 minutes)
# - An indicator as to whether they gamed or not (for later use in filtering and visualisations)

# %%
# Gaming (activity 13)
timeuse_data_temp_13 = timeuse_data[timeuse_cols]

# Replace all activities recorded other than 'Gaming' (13) with NULLs as we don't care about them
timeuse_data_temp_13[timeuse_data_temp_13 != 13] = np.nan

# %%
# Calculate count of 15min slots flagged as gaming per student ID using 'count'
timeuse_data_temp_13['CNT_15M_INTERVALS_COMPGAMES'] = timeuse_data_temp_13.count(axis=1)

# Calculate total time spent by multiplying the count of slots * 15 (as each slot = 15mins)
timeuse_data_temp_13['TOTAL_MINS_COMPGAMES'] = timeuse_data_temp_13.CNT_15M_INTERVALS_COMPGAMES * 15

# Add 2 new columns back to original dataset
timeuse_data = timeuse_data.join(timeuse_data_temp_13[['CNT_15M_INTERVALS_COMPGAMES', 'TOTAL_MINS_COMPGAMES']])

# Create a gaming indicator (1 = Yes, 0 = No)
timeuse_data['COMP_GAMING_IND'] = np.where(timeuse_data['CNT_15M_INTERVALS_COMPGAMES'] > 0, 1, 0)

# %% [markdown]
# ## Merge Cohort Dataset & Time Use Dataset

# %%
# join both datasets using the common 'ID' column for each student
wave1_merged = pd.merge(cohort_data, timeuse_data, how='left', on='ID')

wave1_merged.shape
# Out:
# (8449, 509)

# %% [markdown]
# ## After merge, drop any students missing a Time Use diary

# %%
# Drop anyone present in cohort data with a maths score who did not complete a time-use diary
wave1_merged = wave1_merged[wave1_merged.DiaryDay.isna() == False]

print (f'Final number of rows and columns: {wave1_merged.shape}')
# Out:
# Final number of rows and columns: (6159, 509)

# %% [markdown]
# ## Exploring the clean merged dataset

# %%
# See breakdown of gaming vs no gaming
wave1_merged.COMP_GAMING_IND.value_counts()
# Out:
# 0.0    3866
# 1.0    2293
# Name: COMP_GAMING_IND, dtype: int64

# %% [markdown]
# ## Statistical Testing

# %% [markdown]
# Compare the scaled maths score between those who game and didn't game.
#
# **Null hypothesis:** The maths scores for students who did game = the maths scores for students who didn't game.
#
# **Alternative hypothesis:** The maths scores for students who did game > the maths scores for students who didn't game.

# %%
# Split dataset into 2 groups, those who gamed and those who didn't
students_who_gamed = wave1_merged[wave1_merged.COMP_GAMING_IND == 1]
students_who_didnt_game = wave1_merged[wave1_merged.COMP_GAMING_IND == 0]

# %%
# perform two sample z-test
zscore, pvalue = ztest(students_who_gamed.SCALED_MATHSLS, students_who_didnt_game.SCALED_MATHSLS, value=0, alternative='larger')

confidence_threshold = 0.05 # 95% (1-0.05)

print('Z Score\t:', zscore)
print('P Value\t:', pvalue)

if (1 - pvalue < confidence_threshold):
    print(1 - pvalue)
    print('Null hypothesis is accepted!')
else:
    print(1 - pvalue)
    print('Null hypothesis is rejected. \nAlternate hypothesis is accepted!')
# Out:
# Z Score	: 5.399379714744775
# P Value	: 3.343585105950899e-08
# 0.9999999665641489
# Null hypothesis is rejected.
# Alternate hypothesis is accepted!

# %%
# Add ID back as a column by resetting the index
wave1_merged.reset_index(inplace=True)

# Save clean merged dataset ready for Tableau to import
wave1_merged.to_csv('child_wave_1_merged.csv', index=False)
